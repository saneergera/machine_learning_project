# %%
from matplotlib import pyplot
from scipy.stats import friedmanchisquare
import Orange

# %%
import matplotlib.pyplot as plt
names = ["Descion Tree", "KNN", "NB", "Ensemble Gradient Boosting", "Rule Based" ]
avranks =  [2.8, 2.2, 4, 1, 5 ]
cd = Orange.evaluation.compute_CD(avranks, 3) #tested on 3 datasets
Orange.evaluation.graph_ranks(avranks, names, cd=cd, width=6, textspace=1.5)
print('Critical Difference:', cd)
plt.show()
# Out:
# Critical Difference: 3.5215410914058634
